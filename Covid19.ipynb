# %%
import os 
path="F:\Online IT learning\Python learning\Daily 30mn Python learning\Pandas"
os.chdir(path)

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df= pd.read_csv("WHO-COVID-19-global-data.csv")
df
# Out:
#       Date_reported Country_code      Country WHO_region  New_cases  \
# 0        2020-01-03           AF  Afghanistan       EMRO          0
# 1        2020-01-04           AF  Afghanistan       EMRO          0
# 2        2020-01-05           AF  Afghanistan       EMRO          0
# 3        2020-01-06           AF  Afghanistan       EMRO          0
# 4        2020-01-07           AF  Afghanistan       EMRO          0
# 5        2020-01-08           AF  Afghanistan       EMRO          0
# 6        2020-01-09           AF  Afghanistan       EMRO          0
# 7        2020-01-10           AF  Afghanistan       EMRO          0
# 8        2020-01-11           AF  Afghanistan       EMRO          0
# 9        2020-01-12           AF  Afghanistan       EMRO          0
# 10       2020-01-13           AF  Afghanistan       EMRO          0
# 11       2020-01-14           AF  Afghanistan       EMRO          0
# 12       2020-01-15           AF  Afghanistan       EMRO          0
# ...

# %%
df_index=df.index
df_index
# Out:
# RangeIndex(start=0, stop=86268, step=1)

# %%
df_cols=df.columns
df_cols
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df_index.values
# Out:
# array([    0,     1,     2, ..., 86265, 86266, 86267], dtype=int64)

# %%
df.values
# Out:
# array([['2020-01-03', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-04', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-05', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ...,
#        ['2020-12-29', 'ZW', 'Zimbabwe', ..., 13148, 13, 354],
#        ['2020-12-30', 'ZW', 'Zimbabwe', ..., 13148, 0, 354],
#        ['2020-12-31', 'ZW', 'Zimbabwe', ..., 13625, 6, 360]], dtype=object)

# %%
df.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
df.shape
# Out:
# (86268, 8)

# %%
df.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
df.tail()
# Out:
#       Date_reported Country_code   Country WHO_region  New_cases  \
# 86263    2020-12-27           ZW  Zimbabwe       AFRO         83
# 86264    2020-12-28           ZW  Zimbabwe       AFRO          0
# 86265    2020-12-29           ZW  Zimbabwe       AFRO        185
# 86266    2020-12-30           ZW  Zimbabwe       AFRO          0
# 86267    2020-12-31           ZW  Zimbabwe       AFRO        477
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 86263             12963           0                341
# 86264             12963           0                341
# 86265             13148          13                354
# 86266             13148           0                354
# 86267             13625           6                360

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86268 entries, 0 to 86267
# Data columns (total 8 columns):
# Date_reported        86268 non-null object
# Country_code         85904 non-null object
# Country              86268 non-null object
# WHO_region           86268 non-null object
# New_cases            86268 non-null int64
# Cumulative_cases     86268 non-null int64
# New_deaths           86268 non-null int64
# Cumulative_deaths    86268 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 5.3+ MB

# %%
df.describe()
# Out:
#            New_cases  Cumulative_cases    New_deaths  Cumulative_deaths
# count   86268.000000      8.626800e+04  86268.000000       86268.000000
# mean      944.441195      8.684401e+04     20.842607        2559.126884
# std      6494.096255      6.006321e+05    119.731790       14537.679404
# min    -32952.000000      0.000000e+00   -514.000000           0.000000
# 25%         0.000000      2.000000e+00      0.000000           0.000000
# 50%         2.000000      5.570000e+02      0.000000          10.000000
# 75%       127.000000      1.169100e+04      2.000000         221.000000
# max    402270.000000      1.934679e+07   6409.000000      335789.000000

# %%
df["Country"]
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
# 5        Afghanistan
# 6        Afghanistan
# 7        Afghanistan
# 8        Afghanistan
# 9        Afghanistan
# 10       Afghanistan
# 11       Afghanistan
# 12       Afghanistan
# 13       Afghanistan
# 14       Afghanistan
# 15       Afghanistan
# 16       Afghanistan
# 17       Afghanistan
# 18       Afghanistan
# 19       Afghanistan
# 20       Afghanistan
# 21       Afghanistan
# 22       Afghanistan
# 23       Afghanistan
# 24       Afghanistan
# 25       Afghanistan
# 26       Afghanistan
# 27       Afghanistan
# 28       Afghanistan
# 29       Afghanistan
#             ...
# 86238       Zimbabwe
# 86239       Zimbabwe
# 86240       Zimbabwe
# 86241       Zimbabwe
# 86242       Zimbabwe
# 86243       Zimbabwe
# 86244       Zimbabwe
# 86245       Zimbabwe
# 86246       Zimbabwe
# 86247       Zimbabwe
# 86248       Zimbabwe
# 86249       Zimbabwe
# ...

# %%
df["Country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bonaire',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Côte d’Ivoire', 'Croatia', 'Cuba', 'Curaçao',
#        'Cyprus', 'Czechia', "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Denmark', 'Djibouti',
# ...

# %%
df.columns=[col.strip() for col in df.columns]
df.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
df.Country
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
# 5        Afghanistan
# 6        Afghanistan
# 7        Afghanistan
# 8        Afghanistan
# 9        Afghanistan
# 10       Afghanistan
# 11       Afghanistan
# 12       Afghanistan
# 13       Afghanistan
# 14       Afghanistan
# 15       Afghanistan
# 16       Afghanistan
# 17       Afghanistan
# 18       Afghanistan
# 19       Afghanistan
# 20       Afghanistan
# 21       Afghanistan
# 22       Afghanistan
# 23       Afghanistan
# 24       Afghanistan
# 25       Afghanistan
# 26       Afghanistan
# 27       Afghanistan
# 28       Afghanistan
# 29       Afghanistan
#             ...
# 86238       Zimbabwe
# 86239       Zimbabwe
# 86240       Zimbabwe
# 86241       Zimbabwe
# 86242       Zimbabwe
# 86243       Zimbabwe
# 86244       Zimbabwe
# 86245       Zimbabwe
# 86246       Zimbabwe
# 86247       Zimbabwe
# 86248       Zimbabwe
# 86249       Zimbabwe
# ...

# %%
#kivabe ekta selected raw  k dekhano jay (loc information ja ami dekhte chai tar modde level dite use hoy)
df.loc[1:4,"Country"]
df.loc[1:8, ["Country", "New_cases"]]
# Out:
#        Country  New_cases
# 1  Afghanistan          0
# 2  Afghanistan          0
# 3  Afghanistan          0
# 4  Afghanistan          0
# 5  Afghanistan          0
# 6  Afghanistan          0
# 7  Afghanistan          0
# 8  Afghanistan          0

# %%
df.Country=="United States of America"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 86238    False
# 86239    False
# 86240    False
# 86241    False
# 86242    False
# 86243    False
# 86244    False
# 86245    False
# 86246    False
# 86247    False
# 86248    False
# 86249    False
# 86250    False
# 86251    False
# 86252    False
# 86253    False
# 86254    False
# 86255    False
# 86256    False
# 86257    False
# 86258    False
# 86259    False
# 86260    False
# 86261    False
# 86262    False
# 86263    False
# 86264    False
# ...

# %%
df[df.Country=="United States of America"]
# Out:
#       Date_reported Country_code                   Country WHO_region  \
# 82264    2020-01-03           US  United States of America       AMRO
# 82265    2020-01-04           US  United States of America       AMRO
# 82266    2020-01-05           US  United States of America       AMRO
# 82267    2020-01-06           US  United States of America       AMRO
# 82268    2020-01-07           US  United States of America       AMRO
# 82269    2020-01-08           US  United States of America       AMRO
# 82270    2020-01-09           US  United States of America       AMRO
# 82271    2020-01-10           US  United States of America       AMRO
# 82272    2020-01-11           US  United States of America       AMRO
# 82273    2020-01-12           US  United States of America       AMRO
# 82274    2020-01-13           US  United States of America       AMRO
# 82275    2020-01-14           US  United States of America       AMRO
# ...

# %%
#jodi amra shorto diye kono dekhte chai
df[df.New_deaths>1000]
# Out:
#       Date_reported Country_code                           Country WHO_region  \
# 3186     2020-10-03           AR                         Argentina       AMRO
# 8985     2020-09-08           BO  Bolivia (Plurinational State of)       AMRO
# 10331    2020-05-21           BR                            Brazil       AMRO
# 10333    2020-05-23           BR                            Brazil       AMRO
# 10334    2020-05-24           BR                            Brazil       AMRO
# 10338    2020-05-28           BR                            Brazil       AMRO
# 10339    2020-05-29           BR                            Brazil       AMRO
# 10340    2020-05-30           BR                            Brazil       AMRO
# 10341    2020-05-31           BR                            Brazil       AMRO
# 10345    2020-06-04           BR                            Brazil       AMRO
# 10346    2020-06-05           BR                            Brazil       AMRO
# ...

# %%
df.loc[df.New_deaths>1000, ["New_deaths", "Country"]]
# Out:
#        New_deaths                           Country
# 3186         3351                         Argentina
# 8985         1610  Bolivia (Plurinational State of)
# 10331        1179                            Brazil
# 10333        1188                            Brazil
# 10334        1001                            Brazil
# 10338        1039                            Brazil
# 10339        1086                            Brazil
# 10340        1156                            Brazil
# 10341        1124                            Brazil
# 10345        1262                            Brazil
# 10346        1349                            Brazil
# 10347        1473                            Brazil
# 10348        1005                            Brazil
# 10352        1272                            Brazil
# 10353        1274                            Brazil
# 10354        1239                            Brazil
# 10359        1282                            Brazil
# ...

# %%
df.loc[df.Country_code=="US", ["New_cases"]].max()
# Out:
# New_cases    402270
# dtype: int64

# %%
df.loc[df.Country_code=="US", ["New_cases"]].sum()
# Out:
# New_cases    19346790
# dtype: int64

# %%
df.New_deaths.idxmax()
# Out:
# 82369

# %%
df.loc[df.New_deaths.idxmax(),["Date_reported", "Country", "New_cases"]]
# Out:
# Date_reported                  2020-04-17
# Country          United States of America
# New_cases                           28711
# Name: 82369, dtype: object

# %%
df[df.New_deaths<0]
# Out:
#       Date_reported Country_code                   Country WHO_region  \
# 942      2020-08-04           DZ                   Algeria       AFRO
# 2096     2020-10-05           AO                    Angola       AFRO
# 4157     2020-06-04           AU                 Australia       WPRO
# 5336     2020-08-30           BS                   Bahamas       AMRO
# 11840    2020-07-13           BF              Burkina Faso       AFRO
# 16538    2020-06-09           CG                     Congo       AFRO
# 18425    2020-08-15           CU                      Cuba       AMRO
# 19476    2020-07-05           CZ                   Czechia       EURO
# 19477    2020-07-06           CZ                   Czechia       EURO
# 20515    2020-05-13           DK                   Denmark       EURO
# 23658    2020-12-30           ER                   Eritrea       AFRO
# 24264    2020-08-30           SZ                  Eswatini       AFRO
# ...

# %%
#New column toiri kora 
df["pct_cases"]=(df["New_cases"]/df["Cumulative_cases"])*100
df
# Out:
#       Date_reported Country_code      Country WHO_region  New_cases  \
# 0        2020-01-03           AF  Afghanistan       EMRO          0
# 1        2020-01-04           AF  Afghanistan       EMRO          0
# 2        2020-01-05           AF  Afghanistan       EMRO          0
# 3        2020-01-06           AF  Afghanistan       EMRO          0
# 4        2020-01-07           AF  Afghanistan       EMRO          0
# 5        2020-01-08           AF  Afghanistan       EMRO          0
# 6        2020-01-09           AF  Afghanistan       EMRO          0
# 7        2020-01-10           AF  Afghanistan       EMRO          0
# 8        2020-01-11           AF  Afghanistan       EMRO          0
# 9        2020-01-12           AF  Afghanistan       EMRO          0
# 10       2020-01-13           AF  Afghanistan       EMRO          0
# 11       2020-01-14           AF  Afghanistan       EMRO          0
# 12       2020-01-15           AF  Afghanistan       EMRO          0
# ...
